# %%
import pypsa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
n = pypsa.Network('results/prenetworks/elec_s_37_lvopt___2050.nc')
# Out:
# INFO:pypsa.io:Imported network elec_s_37_lvopt___2050.nc has buses, carriers, generators, global_constraints, lines, links, loads, shapes, storage_units, stores

# %%
biomass_links = n.links[n.links.carrier.str.contains('biomass')]
biomass_links
# Out:
#                                                    bus0  \
# Link
# AL1 0 urban central solid biomass CHP  EU solid biomass
# AT1 0 urban central solid biomass CHP  EU solid biomass
# BA1 0 urban central solid biomass CHP  EU solid biomass
# BE1 0 urban central solid biomass CHP  EU solid biomass
# BG1 0 urban central solid biomass CHP  EU solid biomass
# ...                                                 ...
# SE2 0 urban decentral biomass boiler   EU solid biomass
# SI1 0 rural biomass boiler             EU solid biomass
# SI1 0 urban decentral biomass boiler   EU solid biomass
# SK1 0 rural biomass boiler             EU solid biomass
# SK1 0 urban decentral biomass boiler   EU solid biomass
#
#                                                              bus1  \
# Link
# AL1 0 urban central solid biomass CHP                       AL1 0
# AT1 0 urban central solid biomass CHP                       AT1 0
# BA1 0 urban central solid biomass CHP                       BA1 0
# BE1 0 urban central solid biomass CHP                       BE1 0
# BG1 0 urban central solid biomass CHP                       BG1 0
# ...                                                           ...
# SE2 0 urban decentral biomass boiler   SE2 0 urban decentral heat
# SI1 0 rural biomass boiler                       SI1 0 rural heat
# SI1 0 urban decentral biomass boiler   SI1 0 urban decentral heat
# SK1 0 rural biomass boiler                       SK1 0 rural heat
# SK1 0 urban decentral biomass boiler   SK1 0 urban decentral heat
#
#                                                                carrier  \
# Link
# AL1 0 urban central solid biomass CHP  urban central solid biomass CHP
# AT1 0 urban central solid biomass CHP  urban central solid biomass CHP
# BA1 0 urban central solid biomass CHP  urban central solid biomass CHP
# BE1 0 urban central solid biomass CHP  urban central solid biomass CHP
# BG1 0 urban central solid biomass CHP  urban central solid biomass CHP
# ...                                                                ...
# SE2 0 urban decentral biomass boiler    urban decentral biomass boiler
# SI1 0 rural biomass boiler                        rural biomass boiler
# SI1 0 urban decentral biomass boiler    urban decentral biomass boiler
# SK1 0 rural biomass boiler                        rural biomass boiler
# SK1 0 urban decentral biomass boiler    urban decentral biomass boiler
#
#                                       geometry  length  p_nom tags  \
# Link
# AL1 0 urban central solid biomass CHP              0.0    0.0
# AT1 0 urban central solid biomass CHP              0.0    0.0
# BA1 0 urban central solid biomass CHP              0.0    0.0
# BE1 0 urban central solid biomass CHP              0.0    0.0
# BG1 0 urban central solid biomass CHP              0.0    0.0
# ...                                        ...     ...    ...  ...
# SE2 0 urban decentral biomass boiler               0.0    0.0
# SI1 0 rural biomass boiler                         0.0    0.0
# SI1 0 urban decentral biomass boiler               0.0    0.0
# SK1 0 rural biomass boiler                         0.0    0.0
# SK1 0 urban decentral biomass boiler               0.0    0.0
#
#                                        under_construction  underground  \
# Link
# AL1 0 urban central solid biomass CHP                 NaN          NaN
# AT1 0 urban central solid biomass CHP                 NaN          NaN
# BA1 0 urban central solid biomass CHP                 NaN          NaN
# BE1 0 urban central solid biomass CHP                 NaN          NaN
# BG1 0 urban central solid biomass CHP                 NaN          NaN
# ...                                                   ...          ...
# SE2 0 urban decentral biomass boiler                  NaN          NaN
# SI1 0 rural biomass boiler                            NaN          NaN
# SI1 0 urban decentral biomass boiler                  NaN          NaN
# SK1 0 rural biomass boiler                            NaN          NaN
# SK1 0 urban decentral biomass boiler                  NaN          NaN
#
#                                        p_min_pu  ...  shut_down_cost  \
# Link                                             ...
# AL1 0 urban central solid biomass CHP       0.0  ...             0.0
# AT1 0 urban central solid biomass CHP       0.0  ...             0.0
# BA1 0 urban central solid biomass CHP       0.0  ...             0.0
# BE1 0 urban central solid biomass CHP       0.0  ...             0.0
# BG1 0 urban central solid biomass CHP       0.0  ...             0.0
# ...                                         ...  ...             ...
# SE2 0 urban decentral biomass boiler        0.0  ...             0.0
# SI1 0 rural biomass boiler                  0.0  ...             0.0
# SI1 0 urban decentral biomass boiler        0.0  ...             0.0
# SK1 0 rural biomass boiler                  0.0  ...             0.0
# SK1 0 urban decentral biomass boiler        0.0  ...             0.0
#
#                                        min_up_time  min_down_time  \
# Link
# AL1 0 urban central solid biomass CHP            0              0
# AT1 0 urban central solid biomass CHP            0              0
# BA1 0 urban central solid biomass CHP            0              0
# BE1 0 urban central solid biomass CHP            0              0
# BG1 0 urban central solid biomass CHP            0              0
# ...                                            ...            ...
# SE2 0 urban decentral biomass boiler             0              0
# SI1 0 rural biomass boiler                       0              0
# SI1 0 urban decentral biomass boiler             0              0
# SK1 0 rural biomass boiler                       0              0
# SK1 0 urban decentral biomass boiler             0              0
#
#                                        up_time_before  down_time_before  \
# Link
# AL1 0 urban central solid biomass CHP               1                 0
# AT1 0 urban central solid biomass CHP               1                 0
# BA1 0 urban central solid biomass CHP               1                 0
# BE1 0 urban central solid biomass CHP               1                 0
# BG1 0 urban central solid biomass CHP               1                 0
# ...                                               ...               ...
# SE2 0 urban decentral biomass boiler                1                 0
# SI1 0 rural biomass boiler                          1                 0
# SI1 0 urban decentral biomass boiler                1                 0
# SK1 0 rural biomass boiler                          1                 0
# SK1 0 urban decentral biomass boiler                1                 0
#
#                                        ramp_limit_up  ramp_limit_down  \
# Link
# AL1 0 urban central solid biomass CHP            NaN              NaN
# AT1 0 urban central solid biomass CHP            NaN              NaN
# BA1 0 urban central solid biomass CHP            NaN              NaN
# BE1 0 urban central solid biomass CHP            NaN              NaN
# BG1 0 urban central solid biomass CHP            NaN              NaN
# ...                                              ...              ...
# SE2 0 urban decentral biomass boiler             NaN              NaN
# SI1 0 rural biomass boiler                       NaN              NaN
# SI1 0 urban decentral biomass boiler             NaN              NaN
# SK1 0 rural biomass boiler                       NaN              NaN
# SK1 0 urban decentral biomass boiler             NaN              NaN
#
#                                        ramp_limit_start_up  \
# Link
# AL1 0 urban central solid biomass CHP                  1.0
# AT1 0 urban central solid biomass CHP                  1.0
# BA1 0 urban central solid biomass CHP                  1.0
# BE1 0 urban central solid biomass CHP                  1.0
# BG1 0 urban central solid biomass CHP                  1.0
# ...                                                    ...
# SE2 0 urban decentral biomass boiler                   1.0
# SI1 0 rural biomass boiler                             1.0
# SI1 0 urban decentral biomass boiler                   1.0
# SK1 0 rural biomass boiler                             1.0
# SK1 0 urban decentral biomass boiler                   1.0
#
#                                       ramp_limit_shut_down  p_nom_opt
# Link
# AL1 0 urban central solid biomass CHP                  1.0        0.0
# AT1 0 urban central solid biomass CHP                  1.0        0.0
# BA1 0 urban central solid biomass CHP                  1.0        0.0
# BE1 0 urban central solid biomass CHP                  1.0        0.0
# BG1 0 urban central solid biomass CHP                  1.0        0.0
# ...                                                    ...        ...
# SE2 0 urban decentral biomass boiler                   1.0        0.0
# SI1 0 rural biomass boiler                             1.0        0.0
# SI1 0 urban decentral biomass boiler                   1.0        0.0
# SK1 0 rural biomass boiler                             1.0        0.0
# SK1 0 urban decentral biomass boiler                   1.0        0.0
#
# [148 rows x 46 columns]

# %%
biomass_1 = n.buses[n.buses.index.str.contains('biomass')]
biomass_1
# Out:
#                             v_nom    x     y country control generator  \
# Bus
# EU solid biomass              1.0 -5.5  46.0              PQ
# solid biomass for industry    1.0 -5.5  46.0              PQ
#
#                                                carrier location     unit type  \
# Bus
# EU solid biomass                         solid biomass       EU  MWh_LHV
# solid biomass for industry  solid biomass for industry       EU  MWh_LHV
#
#                             v_mag_pu_set  v_mag_pu_min  v_mag_pu_max  \
# Bus
# EU solid biomass                     1.0           0.0           inf
# solid biomass for industry           1.0           0.0           inf
#
#                            sub_network
# Bus
# EU solid biomass
# solid biomass for industry

# %%
carriers = n.carriers
carriers
# Out:
#                                   co2_emissions    color  \
# Carrier
# AC                                          0.0  #70af1d
# DC                                          0.0  #8a1caf
# nuclear                                     0.0  #ff8c00
# offwind-dc                                  0.0  #74c6f2
# hydro                                       0.0  #298c81
# ...                                         ...      ...
# urban decentral biomass boiler              0.0
# rural ground heat pump                      0.0
# urban decentral resistive heater            0.0
# urban central resistive heater              0.0  #8cdf85
# home battery charger                        0.0  #5e8032
#
#                                                          nice_name  \
# Carrier
# AC                                                              AC
# DC                                                              DC
# nuclear                                                    nuclear
# offwind-dc                                      Offshore Wind (DC)
# hydro                                              Reservoir & Dam
# ...                                                            ...
# urban decentral biomass boiler      urban decentral biomass boiler
# rural ground heat pump                      rural ground heat pump
# urban decentral resistive heater  urban decentral resistive heater
# urban central resistive heater      urban central resistive heater
# home battery charger                          home battery charger
#
#                                   max_growth  max_relative_growth
# Carrier
# AC                                       inf                  0.0
# DC                                       inf                  0.0
# nuclear                                  inf                  0.0
# offwind-dc                               inf                  0.0
# hydro                                    inf                  0.0
# ...                                      ...                  ...
# urban decentral biomass boiler           inf                  0.0
# rural ground heat pump                   inf                  0.0
# urban decentral resistive heater         inf                  0.0
# urban central resistive heater           inf                  0.0
# home battery charger                     inf                  0.0
#
# [97 rows x 5 columns]
